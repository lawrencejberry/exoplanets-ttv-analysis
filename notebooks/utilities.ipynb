# %% [markdown]
# Download ETD data

# %%
import pandas as pd
import urllib 
import json 
from io import BytesIO

etd_data = urllib.request.urlopen('http://var2.astro.cz/ETD/ascii-etd.php?id=1').read()
pd.read_csv(BytesIO(etd_data), encoding="latin", skiprows=3, sep=";", on_bad_lines="skip")
# Out:
#      #       HJDmid  HJDmid Error  Epoch           O-C  Duration  \
# 0   28  55040.65158       0.00093      0  2.455041e+06       NaN
# 1   27  54995.80961       0.00079      0  2.454996e+06       NaN
# 2   26  54994.59691       0.00060      0  2.454995e+06       NaN
# 3   25  54972.78553       0.00044      0  2.454973e+06       NaN
# 4   24  54961.87779       0.00069      0  2.454962e+06       NaN
# 5   23  54955.81712       0.00110      0  2.454956e+06       NaN
# 6   22  54949.75803       0.00065      0  2.454950e+06       NaN
# 7   21  54674.65443       0.00085      0  2.454675e+06       NaN
# 8   20  54629.81483       0.00083      0  2.454630e+06       NaN
# 9   19  54600.72852       0.00031      0  2.454601e+06       NaN
# 10  18  54342.59179       0.00046      0  2.454343e+06       NaN
# 11  17  53936.60226       0.00072      0  2.453937e+06       NaN
# 12  16  53936.59908       0.00045      0  2.453937e+06       NaN
# ...
